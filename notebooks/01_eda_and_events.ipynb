# %%
import pandas as pd
from datetime import datetime

events = [
    {"Date": "2011-02-20", "Event": "Arab Spring / Libya Civil War", "Description": "Supply disruption from Libya unrest drives prices up.", "Category": "Conflict"},
    {"Date": "2014-06-10", "Event": "ISIS Captures Mosul", "Description": "Fears of Iraq supply disruption.", "Category": "Conflict"},
    {"Date": "2014-11-27", "Event": "OPEC No-Cut Decision", "Description": "OPEC maintains output → accelerated 2014-2016 price crash.", "Category": "OPEC Policy"},
    {"Date": "2016-11-30", "Event": "OPEC+ Production Cut Agreement", "Description": "First major coordinated cut with Russia.", "Category": "OPEC Policy"},
    {"Date": "2018-05-08", "Event": "US Exits Iran Nuclear Deal", "Description": "Sanctions reimposed on Iranian oil exports.", "Category": "Sanctions"},
    {"Date": "2019-09-14", "Event": "Drone Attacks on Saudi Aramco", "Description": "Temporary loss of ~5.7M bpd → sharp spike.", "Category": "Conflict"},
    {"Date": "2020-03-08", "Event": "Russia-Saudi Price War Begins", "Description": "Production surge amid COVID demand drop.", "Category": "OPEC Policy"},
    {"Date": "2020-04-12", "Event": "Historic OPEC+ Cuts", "Description": "Record 9.7M bpd cut to stabilize market.", "Category": "OPEC Policy"},
    {"Date": "2020-03-20", "Event": "Global COVID-19 Lockdowns Peak", "Description": "Demand collapse → prices crash.", "Category": "Economic Shock"},
    {"Date": "2022-02-24", "Event": "Russia Invades Ukraine", "Description": "Supply fears + sanctions → price surge to $120+.", "Category": "Conflict"},
    {"Date": "2015-07-14", "Event": "Iran Nuclear Deal (JCPOA)", "Description": "Paved way for increased Iranian supply later.", "Category": "Policy"},
    {"Date": "2021-10-01", "Event": "Post-COVID Demand Recovery", "Description": "Reopening economies + supply constraints.", "Category": "Economic Shock"},
]

events_df = pd.DataFrame(events)
events_df['Date'] = pd.to_datetime(events_df['Date'])
events_df.to_csv(r'C:\Users\hp\Pictures\brent-change-point\brent-change-point\data\raw\events.csv', index=False)
print("Events saved:", len(events_df))
# Out:
# Events saved: 12
